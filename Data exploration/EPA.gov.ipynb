# %%
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # EPA AQS
# ___
# ##### https://aqs.epa.gov/aqsweb/documents/data_api.html#daily
#
# NOTES:
# - Find best API steps (https://docs.airnowapi.org/docs/AirNowAPIFactSheet.pdf)...

# %%
df = pd.read_csv('/Users/kevinmarlis/Downloads/daily_88101_2019.csv')

# %%
df.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           88101    1  30.497478
# 1           1            3        10           88101    1  30.497478
# 2           1            3        10           88101    1  30.497478
# 3           1            3        10           88101    1  30.497478
# 4           1            3        10           88101    1  30.497478
#
#    Longitude  Datum            Parameter Name Sample Duration  ...   AQI  \
# 0 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  18.0
# 1 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  35.0
# 2 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  14.0
# 3 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  36.0
# 4 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR  ...  38.0
#
#   Method Code                                        Method Name  \
# ...

# %%
cols = df.columns
cols
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
#        'Observation Count', 'Observation Percent', 'Arithmetic Mean',
#        '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
#        'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
#        'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
cols_to_drop = ['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
       'Latitude', 'Longitude', 'Address']

# %%
df = df.drop(cols_to_drop, axis=1)

# %%
df.head()
# Out:
#    Datum            Parameter Name Sample Duration Pollutant Standard  \
# 0  NAD83  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 1  NAD83  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 2  NAD83  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 3  NAD83  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 4  NAD83  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
#
#    Date Local             Units of Measure Event Type  Observation Count  \
# 0  2019-01-03  Micrograms/cubic meter (LC)       None                  1
# 1  2019-01-06  Micrograms/cubic meter (LC)       None                  1
# 2  2019-01-09  Micrograms/cubic meter (LC)       None                  1
# 3  2019-01-12  Micrograms/cubic meter (LC)       None                  1
# 4  2019-01-15  Micrograms/cubic meter (LC)       None                  1
#
#    Observation Percent  Arithmetic Mean  ...  1st Max Hour   AQI  Method Code  \
# ...

# %%
lac_df = df.loc[df['County Name'] == 'Los Angeles']

# %%
lac_df
# Out:
#        Datum            Parameter Name Sample Duration Pollutant Standard  \
# 40254  WGS84  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 40255  WGS84  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 40256  WGS84  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 40257  WGS84  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# 40258  WGS84  PM2.5 - Local Conditions         24 HOUR  PM25 24-hour 2012
# ...      ...                       ...             ...                ...
# 43867  NAD83  PM2.5 - Local Conditions   24-HR BLK AVG  PM25 24-hour 2012
# 43868  NAD83  PM2.5 - Local Conditions   24-HR BLK AVG  PM25 24-hour 2012
# 43869  NAD83  PM2.5 - Local Conditions   24-HR BLK AVG  PM25 24-hour 2012
# 43870  NAD83  PM2.5 - Local Conditions   24-HR BLK AVG  PM25 24-hour 2012
# 43871  NAD83  PM2.5 - Local Conditions   24-HR BLK AVG  PM25 24-hour 2012
#
#        Date Local             Units of Measure Event Type  Observation Count  \
# ...

# %%
lac_df.shape
# Out:
# (3618, 21)
