# %%
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
# %matplotlib inline
pd.set_option("display.max.columns", None)

# %%
df = pd.read_stata('/Users/kevinmarlis/Downloads/adult_2018_stata/ADULT.dta')

# %%
df.head()
# Out:
#            aa5c          aa5g        ab1 ab17          ab40          ab41  \
# 0  INAPPLICABLE  INAPPLICABLE  EXCELLENT   NO  INAPPLICABLE  INAPPLICABLE
# 1  INAPPLICABLE  INAPPLICABLE  EXCELLENT  YES           YES            NO
# 2  INAPPLICABLE  INAPPLICABLE       FAIR   NO  INAPPLICABLE  INAPPLICABLE
# 3  INAPPLICABLE  INAPPLICABLE       POOR   NO  INAPPLICABLE  INAPPLICABLE
# 4  INAPPLICABLE  INAPPLICABLE  VERY GOOD   NO  INAPPLICABLE  INAPPLICABLE
#
#           ah13a          ab43          ab98 ab22 ab99          ab24  \
# 0  INAPPLICABLE  INAPPLICABLE  INAPPLICABLE   NO  YES  INAPPLICABLE
# 1            NO            NO  INAPPLICABLE   NO   NO  INAPPLICABLE
# 2  INAPPLICABLE  INAPPLICABLE  INAPPLICABLE   NO  YES  INAPPLICABLE
# 3  INAPPLICABLE  INAPPLICABLE  INAPPLICABLE   NO   NO  INAPPLICABLE
# 4  INAPPLICABLE  INAPPLICABLE  INAPPLICABLE   NO   NO  INAPPLICABLE
#
#            ab25          ab63         ab112          ab81 ab29 ab34  \
# ...

# %%
len(df.columns)
# Out:
# 494

# %%
df.shape
# Out:
# (21177, 494)

# %%
df.columns
# Out:
# Index(['aa5c', 'aa5g', 'ab1', 'ab17', 'ab40', 'ab41', 'ah13a', 'ab43', 'ab98',
#        'ab22',
#        ...
#        'rakedw71', 'rakedw72', 'rakedw73', 'rakedw74', 'rakedw75', 'rakedw76',
#        'rakedw77', 'rakedw78', 'rakedw79', 'rakedw80'],
#       dtype='object', length=494)

# %%
'cb' in df.columns
# Out:
# False

# %%
Asthma = AB17 (ever told yes by doctor)
Heart disease = AB34 (ever told yes by doctor)
Heart failure = AB52 (ever told yes by doctor)
