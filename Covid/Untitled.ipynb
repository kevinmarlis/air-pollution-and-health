# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import missingno as msno

# %% [markdown]
# ### Case Rate
# Cases normalized by 100,000
#
# ### Cases
# Total cases
#
# ### Death Rate
# Deaths normalized by 100,000
#
# ### Deaths
# Total deaths

# %%
path = '/Users/kevinmarlis/Downloads/county_storage-2.csv'
df = pd.read_csv(path)
df.head()
# Out:
#          Date   case_rate cases death_rate deaths              location  \
# 0  04/15/2020  100.560000    21        NaN    NaN  CITY OF AGOURA HILLS
# 1  04/15/2020   42.660000    37        NaN    NaN      CITY OF ALHAMBRA
# 2  04/15/2020   43.290000    25        NaN    NaN       CITY OF ARCADIA
# 3  04/15/2020   29.770000     5        NaN    NaN       CITY OF ARTESIA
# 4  04/15/2020           0     0        NaN    NaN        CITY OF AVALON
#
#    OBJECTID
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4

# %%
df = df.drop(df[df.location  == 'CITY/COMMUNITY'].index)
df = df.drop(['OBJECTID'], axis=1)

# %%
neighborhoods = list(df.location.unique())

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df[df.deaths.isnull()]
# Out:
#             Date   case_rate cases death_rate deaths  \
# 0     04/15/2020  100.560000    21        NaN    NaN
# 1     04/15/2020   42.660000    37        NaN    NaN
# 2     04/15/2020   43.290000    25        NaN    NaN
# 3     04/15/2020   29.770000     5        NaN    NaN
# 4     04/15/2020           0     0        NaN    NaN
# ...          ...         ...   ...        ...    ...
# 9504  05/17/2020   81.460000     3        NaN    NaN
# 9505  05/17/2020  264.270000    10        NaN    NaN
# 9506  05/17/2020           0     0        NaN    NaN
# 9507  05/17/2020  332.250000   116        NaN    NaN
# 9508  05/17/2020  165.920000    10        NaN    NaN
#
#                                 location  OBJECTID
# 0                   CITY OF AGOURA HILLS         0
# 1                       CITY OF ALHAMBRA         1
# 2                        CITY OF ARCADIA         2
# 3                        CITY OF ARTESIA         3
# 4                         CITY OF AVALON         4
# ...                                  ...       ...
# 9504  UNINCORPORATED - WHITE FENCE FARMS      9504
# 9505           UNINCORPORATED - WHITTIER      9505
# 9506   UNINCORPORATED - WHITTIER NARROWS      9506
# 9507        UNINCORPORATED - WILLOWBROOK      9507
# 9508           UNINCORPORATED - WISEBURN      9508
#
# [9509 rows x 7 columns]
